# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import rasterio as rio
import earthpy.plot as ep
# Out:
# /Users/tylerlogie/opt/anaconda3/envs/geostats_env/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %%
filepath = "../RawData/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9_vert_disp.tif"
with rio.open(filepath) as vert_disp:
    vert = vert_disp.read(1)

# %%
type(vert)
# Out:
# numpy.ndarray

# %%
ep.plot_bands(vert,
              title="Vertical Displacement in Outer Banks \n before and after Hurricane Michael (2018)",
              cmap="seismic")

plt.show()

# %%
filepath = "../RawData/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9_dem.tif"
with rio.open(filepath) as dem_net:
    dem = dem_net.read(1)

# %%
ep.plot_bands(dem,
              title="DEM used to generate vertical displacement",
              cmap="Greys")

plt.show()

# %%
filepath = "../RawData/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9_wrapped_phase.tif"
with rio.open(filepath) as wrapped:
    wrap = wrapped.read(1)

# %%
ep.plot_bands(wrap,
              title="Wrapped interferogram",
              cmap="twilight")

plt.show()

# %%
filepath = "../RawData/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9_unw_phase.tif"
with rio.open(filepath) as unwrapped:
    unwrap = unwrapped.read(1)

# %%
ep.plot_bands(unwrap,
              title="Unwrapped interferogram",
              cmap="nipy_spectral")

plt.show()

# %%
filepath = "../RawData/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9_amp.tif"
with rio.open(filepath) as backscatter:
    scatter = backscatter.read(1)

# %%
ep.plot_bands(scatter,
              title="backscatter",
              cmap="inferno")

plt.show()

# %%
filepath = "../RawData/10_03_pair/S1AA_20181003T225747_20181027T225747_VVP024_INT80_G_ueF_33F5/S1AA_20181003T225747_20181027T225747_VVP024_INT80_G_ueF_33F5_unw_phase.tif"
with rio.open(filepath) as unwrapped2:
    unwrap2 = unwrapped2.read(1)

# %%
ep.plot_bands(unwrap2,
              title="Unwrapped Interferogram 10_03")

plt.show()

# %%
filepath = "../RawData/10_03_pair/S1AA_20181003T225747_20181027T225747_VVP024_INT80_G_ueF_33F5/S1AA_20181003T225747_20181027T225747_VVP024_INT80_G_ueF_33F5_unw_phase.png"
with rio.open(filepath) as unwrappedpng:
    unwrappng = unwrappedpng.read(1)

# %%
ep.plot_bands(unwrappng,
              title="Unwrapped Interferogram 10_03 PNG")

plt.show()

# %%
filepath = "../RawData/S1AA_20181008T230552_20181125T230551_VVP048_INT80_G_weF_61C9/"
with rio.open(filepath) as unwrappedpng:
    unwrappng = unwrappedpng.read(1)

# %%
import math
#Estimate displacement using Band Maths
lam = #C band SAR wavelength
delta = #unwrapped phase difference
vert_disp = (0.056 * unwrap2) / (-4 * math.pi() * cos(rad(incident_angle)))
